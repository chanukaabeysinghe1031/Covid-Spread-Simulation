# %% [markdown]
# <a href="https://colab.research.google.com/github/chanukaabeysinghe1031/Covid-Spread-Simulation/blob/main/Assignment_9_Edition_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##26/12 3.40 AM
##########################################################################################################
#  * DATE       : 23-11-2021
#  * COURSE     : PROGRAMMING QUEST (CO2210)
#  * TITLE      : QUEST 09 - Simulating COVID-19 spread in a conceptual community
#  * AUTHOR     : GROUP11
#  ******************************************************************************************************
#  * MEMBERS    : 19/ENG/121-A.P.Maduwantha, 19/ENG/107-Virudaka  AND 18/ENG/002-C. Abeysinghe
##########################################################################################################
import random
import math
import matplotlib.pyplot as plt


AGE_TYPE_SENIOR = 3
AGE_TYPE_MIDDLE = 2
AGE_TYPE_CHILDREN = 1

totalInfected = 0
totalHospitalized = 0
totalRecovered = 0
totalDeath = 0
stillInHospital = 0
day = 1
# noOfFamilyMembers = 2
# wearingMask = 0

class Person:
    
    
    # totalProbability = 0
  
    global day
    def __init__(self, ageType, noOfFamilyMembers, wearingMask,familyNO,count):
        self.isInfected = False
        self.reduceProbability=0
        self.familyProbability=0
        self.suspiciousDays = 0
        self.infectedDays = 0 
        self.ageType = ageType
        self.noOfFamilyMembers = noOfFamilyMembers
        self.wearingMask = wearingMask
        self.familyNO = familyNO,
        self.id= count
        
        
        if ageType==3:
            self.ageProbability = random.randint(35,60)
        if ageType==2:
            self.ageProbability = random.randint(15,40)
        if ageType==1:
            self.ageProbability = random.randint(10,20)

        if wearingMask == 1:
            self.reduceProbability = random.randint(5,10)

    def positive():
      self.isInfected = True
      return self.isInfected

    def isFamilyMember(self,familyNumber):
        # family number 100001 does not belong to any family
        if familyNumber == self.familyNO and self.familyNO != 100001:
            self.familyProbability = random.randint(40,80)
            return True

    def increaseHospitalizeDays(self):
        self.infectedDays = self.infectedDays + 1
        return self.infectedDays

    def increaseDay(self):
        self.suspiciousDays = self.suspiciousDays + 1
        return self.suspiciousDays

    def printPerson(self):
        totalProbability = self.ageProbability + self.familyProbability - self.reduceProbability
        value = self.findInfected()
        if(value == 1):
            print('Infected') 
        else: 
            print('Not Infected')
        print('___________________')
        print('Infected Day : ',self.infectedDays)
        print('Age Type : ', self.ageType)
        print('Age Probability : ', self.ageProbability)
        print('Wearing Mask : ', self.wearingMask)
        print('Reduce Probability : ', self.reduceProbability)
        print('Family NO : ', self.familyNO)
        print('Family Probability : ', self.familyProbability)
        print('Total Probability : ', totalProbability)
        print('=============================================================')

    # totalProbability = ageProbability + familyProbability -reduceProbability
    def findInfected(self):
        totalProbability = self.ageProbability + self.familyProbability - self.reduceProbability
        # print('Total Probability : ', totalProbability)
        #take random no and check the person infected or not
        randomProbability = random.randint(1,100)
        # print('Random Probability : ', randomProbability)
        if totalProbability >= randomProbability:
        # if totalProbability >= 100:
            return 1

 #########################################################################################################  
objectArray = []    #families
indexList = []      #index of persons
idxLst = []
patientList = []
previousDayPatientList = [] 
finalList = []
#there are 100000 families

count =0 
for family in range(0, 100000):
    noOfFamilyMembers = random.randint(2,7)
    for member in range(0, noOfFamilyMembers):
        ageType = random.randint(1,3)
        wearingMask = random.randint(0,1)
        objectArray.append(Person(ageType, noOfFamilyMembers, wearingMask, family,count))
        count = count+1

#family id 100001 means no family
for alone in range(0, 1000000-len(objectArray)):
    ageType = random.randint(1,3)
    wearingMask = random.randint(0,1)
    objectArray.append(Person(ageType, noOfFamilyMembers, wearingMask, 100001,count))
    count = count+1

#Assume that the first person in the array is infected
#if travel restriction is there then the infected person will contact with 0-20 people out of family
Id = 0
indexList.append(Id)
previousDayPatientList = []
patientList.append(objectArray[Id])
previousDayPatientList.append(objectArray[Id])
objectArray[Id].positive
infectedAtDay = 0
totalHospitalizedAtDay = 0

##################################################################################################################
def simulate(patient):
    # global totalInfected
    # global totalHospitalized
    outPeople = random.randint(5,20)    #not family members
    familyNum = patient.familyNO
    #objects are sorted according to family number
    #maximum number of people in a family is 7
    #therefore we can check 7 objects forward and 7 objects backward if array allows

    objectId = objectArray.index(patient)
    if objectId-7 >= 0:
        for i in range(objectId-7, objectId):
            family=objectArray[i].isFamilyMember(familyNum)    #check if the person is family member and set the probability
            if family==True:
                if indexList.count(i)==0:
                    indexList.append(i)

    if objectId+7 < len(objectArray):
        for i in range(objectId+1, objectId+7):
            family=objectArray[i].isFamilyMember(familyNum)    #check if the person is family member and set the probability
            if family==True:
                if indexList.count(i)==0:
                    indexList.append(i)

    #remove duplicates
    # idxLst = list(dict.fromkeys(indexList))
    #take random list 
    randomOuterPeoples = []
    randomOuterPeoples = random.sample(range(0, len(objectArray)), outPeople)

    #check person can infected or not
    for person in randomOuterPeoples:
        personFamily = patient.familyNO
        isAMembers=patient.isFamilyMember(personFamily)
        if isAMembers==False:
            #family members are already taken to check
            if indexList.count(person)==0:
                indexList.append(person)
  
    global totalHospitalizedAtDay
    global infectedAtDay
    for check in indexList:
        # totalHospitalizedAtDay = 0
        #check the list once a day
        objectArray[check].increaseDay()
        #remove the index from the list which more than 10 days old
        if (len(indexList)>=1 and objectArray[check].suspiciousDays > 10):
            indexList.remove(check)
        isInfected = objectArray[check].findInfected()
        if isInfected == 1 or objectArray[check].isInfected:
            objectArray[check].positive
            # objectArray[check].printPerson()
            infectedAtDay = infectedAtDay + 1
            #assume that the person is infected, immediately go to hospital
            totalHospitalizedAtDay = totalHospitalizedAtDay + 1
            #if infected that person will not check any more because he/she has immunity for 6 to 7 months
            patientList.append(objectArray[check])  #add the person to the patient list
            # print(patientList)
            # objectArray.remove(objectArray[check])  #remove the patient from the object array
            # if indexList.count(check)>0:
            #     indexList.remove(check)

    return totalHospitalizedAtDay, infectedAtDay
            

dailyInfected = []
dailyHospitalized = [] 
dailyRecovered = []
dailyDeaths = []

for day in range(1,51):
    list3 = list(dict.fromkeys(patientList))
    print("Previous Day patients at day begining",len(patientList))
    # patientList.clear()
    totalDeathAtDay = 0
    recoveredAtDay = 0 
    
    count = 0 
    for person in list3:
        totalHospitalizedAtDay, infectedAtDay = simulate(person)


    totalInfected = totalInfected + infectedAtDay
    totalHospitalized = totalHospitalized + totalHospitalizedAtDay
    dailyInfected.append(infectedAtDay)
    dailyHospitalized.append(totalHospitalizedAtDay)
    print('|Total Infected :         |', totalInfected) 
  
    #update pateint list daily
    count = 0 
    for patient in patientList:
        patient.increaseHospitalizeDays()   #INCREASE THE DAYS OF HOSPITALIZED
        count = count+1
        # patient.printPerson()
        if patient.infectedDays >=10:
            recoveredAtDay = recoveredAtDay + 1
            stillInHospital = totalHospitalized - 1


    #take 0.1 of hospitalized people die
    totalDeathAtDay = math.floor(stillInHospital*0.001)
    totalDeath = totalDeath + totalDeathAtDay
    totalRecovered = totalHospitalized - totalDeath
    dailyRecovered.append(totalRecovered)
    dailyDeaths.append(totalDeath)
    print('Day : ', day)
    
    dailyList = [infectedAtDay, totalHospitalizedAtDay, totalDeathAtDay, recoveredAtDay]
    finalList.append(dailyList)
    # print('|Total Infected :         |', totalInfected)
    print('Total infected at day : ', infectedAtDay)
    print('Total hospitalized at day : ', totalHospitalizedAtDay)
    # print('Total recovered at day : ', totalRecovered)
    # print('Total death at day : ', totalDeath)
    # infectedAtDay = 0
    # totalHospitalizedAtDay = 0
    print('#####################################################')
    # previousDayPatientList = patientList 
    # patientList.clear()

    
print('=====================================================')
print('|Total Infected :         |', totalInfected)
print('|Totals Hospitalized :    |', totalHospitalized)
print('|Total Recovered :        |', totalRecovered)
print('|Total Death :            |', totalDeath)
print('=====================================================')

plt.plot(dailyInfected)
plt.ylabel('Infected Per Day')
plt.show()

plt.plot(dailyHospitalized)
plt.ylabel('Hospitalized Per Day')
plt.show()

plt.plot(dailyRecovered)
plt.ylabel('Recovered Per Day')
plt.show()
plt.plot(dailyDeaths)
plt.ylabel('Deaths Per Day')
plt.show()
# Out:
# Previous Day patients at day begining 1
# |Total Infected :         | 5
# Day :  1
# Total infected at day :  5
# Total hospitalized at day :  5
# #####################################################
# Previous Day patients at day begining 6
# |Total Infected :         | 30
# Day :  2
# Total infected at day :  25
# Total hospitalized at day :  25
# #####################################################
# Previous Day patients at day begining 26
# |Total Infected :         | 74
# Day :  3
# Total infected at day :  44
# Total hospitalized at day :  44
# #####################################################
# Previous Day patients at day begining 45
# |Total Infected :         | 125
# Day :  4
# Total infected at day :  51
# Total hospitalized at day :  51
# #####################################################
# Previous Day patients at day begining 52
# |Total Infected :         | 181
# Day :  5
# Total infected at day :  56
# Total hospitalized at day :  56
# #####################################################
# Previous Day patients at day begining 57
# |Total Infected :         | 243
# Day :  6
# Total infected at day :  62
# Total hospitalized at day :  62
# #####################################################
# Previous Day patients at day begining 63
# |Total Infected :         | 310
# Day :  7
# Total infected at day :  67
# Total hospitalized at day :  67
# #####################################################
# Previous Day patients at day begining 68
# |Total Infected :         | 384
# Day :  8
# Total infected at day :  74
# Total hospitalized at day :  74
# #####################################################
# Previous Day patients at day begining 75
# |Total Infected :         | 465
# Day :  9
# Total infected at day :  81
# Total hospitalized at day :  81
# #####################################################
# Previous Day patients at day begining 82
# |Total Infected :         | 551
# Day :  10
# Total infected at day :  86
# Total hospitalized at day :  86
# #####################################################
# Previous Day patients at day begining 87
# |Total Infected :         | 641
# Day :  11
# Total infected at day :  90
# Total hospitalized at day :  90
# #####################################################
# Previous Day patients at day begining 91
# |Total Infected :         | 737
# Day :  12
# Total infected at day :  96
# Total hospitalized at day :  96
# #####################################################
# Previous Day patients at day begining 97
# |Total Infected :         | 840
# Day :  13
# Total infected at day :  103
# Total hospitalized at day :  103
# #####################################################
# Previous Day patients at day begining 104
# |Total Infected :         | 950
# Day :  14
# Total infected at day :  110
# Total hospitalized at day :  110
# #####################################################
# Previous Day patients at day begining 111
# |Total Infected :         | 1066
# Day :  15
# Total infected at day :  116
# Total hospitalized at day :  116
# #####################################################
# Previous Day patients at day begining 117
# |Total Infected :         | 1186
# Day :  16
# Total infected at day :  120
# Total hospitalized at day :  120
# #####################################################
# Previous Day patients at day begining 121
# |Total Infected :         | 1310
# Day :  17
# Total infected at day :  124
# Total hospitalized at day :  124
# #####################################################
# Previous Day patients at day begining 125
# |Total Infected :         | 1439
# Day :  18
# Total infected at day :  129
# Total hospitalized at day :  129
# #####################################################
# Previous Day patients at day begining 130
# |Total Infected :         | 1572
# Day :  19
# Total infected at day :  133
# Total hospitalized at day :  133
# #####################################################
# Previous Day patients at day begining 134
# |Total Infected :         | 1711
# Day :  20
# Total infected at day :  139
# Total hospitalized at day :  139
# #####################################################
# Previous Day patients at day begining 140
# |Total Infected :         | 1856
# Day :  21
# Total infected at day :  145
# Total hospitalized at day :  145
# #####################################################
# Previous Day patients at day begining 146
# |Total Infected :         | 2008
# Day :  22
# Total infected at day :  152
# Total hospitalized at day :  152
# #####################################################
# Previous Day patients at day begining 153
# |Total Infected :         | 2167
# Day :  23
# Total infected at day :  159
# Total hospitalized at day :  159
# #####################################################
# Previous Day patients at day begining 160
# |Total Infected :         | 2333
# Day :  24
# Total infected at day :  166
# Total hospitalized at day :  166
# #####################################################
# Previous Day patients at day begining 167
# |Total Infected :         | 2505
# Day :  25
# Total infected at day :  172
# Total hospitalized at day :  172
# #####################################################
# Previous Day patients at day begining 173
# |Total Infected :         | 2682
# Day :  26
# Total infected at day :  177
# Total hospitalized at day :  177
# #####################################################
# Previous Day patients at day begining 178
# |Total Infected :         | 2865
# Day :  27
# Total infected at day :  183
# Total hospitalized at day :  183
# #####################################################
# Previous Day patients at day begining 184
# |Total Infected :         | 3053
# Day :  28
# Total infected at day :  188
# Total hospitalized at day :  188
# #####################################################
# Previous Day patients at day begining 189
# |Total Infected :         | 3248
# Day :  29
# Total infected at day :  195
# Total hospitalized at day :  195
# #####################################################
# Previous Day patients at day begining 196
# |Total Infected :         | 3449
# Day :  30
# Total infected at day :  201
# Total hospitalized at day :  201
# #####################################################
# Previous Day patients at day begining 202
# |Total Infected :         | 3657
# Day :  31
# Total infected at day :  208
# Total hospitalized at day :  208
# #####################################################
# Previous Day patients at day begining 209
# |Total Infected :         | 3872
# Day :  32
# Total infected at day :  215
# Total hospitalized at day :  215
# #####################################################
# Previous Day patients at day begining 216
# |Total Infected :         | 4092
# Day :  33
# Total infected at day :  220
# Total hospitalized at day :  220
# #####################################################
# Previous Day patients at day begining 221
# |Total Infected :         | 4318
# Day :  34
# Total infected at day :  226
# Total hospitalized at day :  226
# #####################################################
# Previous Day patients at day begining 227
# |Total Infected :         | 4551
# Day :  35
# Total infected at day :  233
# Total hospitalized at day :  233
# #####################################################
# Previous Day patients at day begining 234
# |Total Infected :         | 4788
# Day :  36
# Total infected at day :  237
# Total hospitalized at day :  237
# #####################################################
# Previous Day patients at day begining 238
# |Total Infected :         | 5029
# Day :  37
# Total infected at day :  241
# Total hospitalized at day :  241
# #####################################################
# Previous Day patients at day begining 242
# |Total Infected :         | 5277
# Day :  38
# Total infected at day :  248
# Total hospitalized at day :  248
# #####################################################
# Previous Day patients at day begining 249
# |Total Infected :         | 5531
# Day :  39
# Total infected at day :  254
# Total hospitalized at day :  254
# #####################################################
# Previous Day patients at day begining 255
# |Total Infected :         | 5791
# Day :  40
# Total infected at day :  260
# Total hospitalized at day :  260
# #####################################################
# Previous Day patients at day begining 261
# |Total Infected :         | 6057
# Day :  41
# Total infected at day :  266
# Total hospitalized at day :  266
# #####################################################
# Previous Day patients at day begining 267
# |Total Infected :         | 6329
# Day :  42
# Total infected at day :  272
# Total hospitalized at day :  272
# #####################################################
# Previous Day patients at day begining 273
# |Total Infected :         | 6608
# Day :  43
# Total infected at day :  279
# Total hospitalized at day :  279
# #####################################################
# Previous Day patients at day begining 280
# |Total Infected :         | 6891
# Day :  44
# Total infected at day :  283
# Total hospitalized at day :  283
# #####################################################
# Previous Day patients at day begining 284
# |Total Infected :         | 7180
# Day :  45
# Total infected at day :  289
# Total hospitalized at day :  289
# #####################################################
# Previous Day patients at day begining 290
# |Total Infected :         | 7476
# Day :  46
# Total infected at day :  296
# Total hospitalized at day :  296
# #####################################################
# Previous Day patients at day begining 297
# |Total Infected :         | 7776
# Day :  47
# Total infected at day :  300
# Total hospitalized at day :  300
# #####################################################
# Previous Day patients at day begining 301
# |Total Infected :         | 8082
# Day :  48
# Total infected at day :  306
# Total hospitalized at day :  306
# #####################################################
# Previous Day patients at day begining 307
# |Total Infected :         | 8395
# Day :  49
# Total infected at day :  313
# Total hospitalized at day :  313
# #####################################################
# Previous Day patients at day begining 314
# |Total Infected :         | 8714
# Day :  50
# Total infected at day :  319
# Total hospitalized at day :  319
# #####################################################
# =====================================================
# |Total Infected :         | 8714
# |Totals Hospitalized :    | 8714
# |Total Recovered :        | 8575
# |Total Death :            | 139
# =====================================================

# %%
##26/12 3.40 AM
##########################################################################################################
#  * DATE       : 23-11-2021
#  * COURSE     : PROGRAMMING QUEST (CO2210)
#  * TITLE      : QUEST 09 - Simulating COVID-19 spread in a conceptual community
#  * AUTHOR     : GROUP11
#  ******************************************************************************************************
#  * MEMBERS    : 19/ENG/121-A.P.Maduwantha, 19/ENG/107-Virudaka  AND 18/ENG/002-C. Abeysinghe
##########################################################################################################
import random
import math
import matplotlib.pyplot as plt


AGE_TYPE_SENIOR = 3
AGE_TYPE_MIDDLE = 2
AGE_TYPE_CHILDREN = 1

totalInfected = 0
totalHospitalized = 0
totalRecovered = 0
totalDeath = 0
stillInHospital = 0
day = 1
# noOfFamilyMembers = 2
# wearingMask = 0

class Person:
    
    
    # totalProbability = 0
  
    global day
    def __init__(self, ageType, noOfFamilyMembers, wearingMask,familyNO,count):
        self.isInfected = False
        self.reduceProbability=0
        self.familyProbability=0
        self.suspiciousDays = 0
        self.infectedDays = 0 
        self.ageType = ageType
        self.noOfFamilyMembers = noOfFamilyMembers
        self.wearingMask = wearingMask
        self.familyNO = familyNO,
        self.id= count
        
        
        if ageType==3:
            self.ageProbability = random.randint(35,60)
        if ageType==2:
            self.ageProbability = random.randint(15,40)
        if ageType==1:
            self.ageProbability = random.randint(10,20)

        if wearingMask == 1:
            self.reduceProbability = random.randint(5,10)

    def positive():
      self.isInfected = True
      return self.isInfected

    def isFamilyMember(self,familyNumber):
        # family number 100001 does not belong to any family
        if familyNumber == self.familyNO and self.familyNO != 100001:
            self.familyProbability = random.randint(40,80)
            return True

    def increaseHospitalizeDays(self):
        self.infectedDays = self.infectedDays + 1
        return self.infectedDays

    def increaseDay(self):
        self.suspiciousDays = self.suspiciousDays + 1
        return self.suspiciousDays

    def printPerson(self):
        totalProbability = self.ageProbability + self.familyProbability - self.reduceProbability
        value = self.findInfected()
        if(value == 1):
            print('Infected') 
        else: 
            print('Not Infected')
        print('___________________')
        print('Infected Day : ',self.infectedDays)
        print('Age Type : ', self.ageType)
        print('Age Probability : ', self.ageProbability)
        print('Wearing Mask : ', self.wearingMask)
        print('Reduce Probability : ', self.reduceProbability)
        print('Family NO : ', self.familyNO)
        print('Family Probability : ', self.familyProbability)
        print('Total Probability : ', totalProbability)
        print('=============================================================')

    # totalProbability = ageProbability + familyProbability -reduceProbability
    def findInfected(self):
        totalProbability = self.ageProbability + self.familyProbability - self.reduceProbability
        # print('Total Probability : ', totalProbability)
        #take random no and check the person infected or not
        randomProbability = random.randint(1,100)
        # print('Random Probability : ', randomProbability)
        if totalProbability >= randomProbability:
        # if totalProbability >= 100:
            return 1

 #########################################################################################################  
objectArray = []    #families
indexList = []      #index of persons
idxLst = []
patientList = []
previousDayPatientList = [] 
finalList = []
wearingMask = 0
#there are 100000 families

count =0 
for family in range(0, 100000):
    noOfFamilyMembers = random.randint(2,7)
    for member in range(0, noOfFamilyMembers):
        ageType = random.randint(1,3)
        wearingMask = random.randint(0,1)
        objectArray.append(Person(ageType, noOfFamilyMembers, wearingMask, family,count))
        count = count+1

#family id 100001 means no family
for alone in range(0, 1000000-len(objectArray)):
    ageType = random.randint(1,3)
    wearingMask = random.randint(0,1)
    objectArray.append(Person(ageType, noOfFamilyMembers, wearingMask, 100001,count))
    count = count+1

#Assume that the first person in the array is infected
#if travel restriction is there then the infected person will contact with 0-20 people out of family
Id = 0
indexList.append(Id)
previousDayPatientList = []
patientList.append(objectArray[Id])
previousDayPatientList.append(objectArray[Id])
objectArray[Id].positive
infectedAtDay = 0
totalHospitalizedAtDay = 0
contactOutsidePeopleUpperLimit = 20
##################################################################################################################
def simulate(patient):
    # global totalInfected
    # global totalHospitalized
    global contactOutsidePeopleUpperLimit
    outPeople = random.randint(5,contactOutsidePeopleUpperLimit)    #not family members
    familyNum = patient.familyNO
    #objects are sorted according to family number
    #maximum number of people in a family is 7
    #therefore we can check 7 objects forward and 7 objects backward if array allows

    objectId = objectArray.index(patient)
    if objectId-7 >= 0:
        for i in range(objectId-7, objectId):
            family=objectArray[i].isFamilyMember(familyNum)    #check if the person is family member and set the probability
            if family==True:
                if indexList.count(i)==0:
                    indexList.append(i)

    if objectId+7 < len(objectArray):
        for i in range(objectId+1, objectId+7):
            family=objectArray[i].isFamilyMember(familyNum)    #check if the person is family member and set the probability
            if family==True:
                if indexList.count(i)==0:
                    indexList.append(i)

    #remove duplicates
    # idxLst = list(dict.fromkeys(indexList))
    #take random list 
    randomOuterPeoples = []
    randomOuterPeoples = random.sample(range(0, len(objectArray)), outPeople)

    #check person can infected or not
    for person in randomOuterPeoples:
        personFamily = patient.familyNO
        isAMembers=patient.isFamilyMember(personFamily)
        if isAMembers==False:
            #family members are already taken to check
            if indexList.count(person)==0:
                indexList.append(person)
  
    global totalHospitalizedAtDay
    global infectedAtDay
    for check in indexList:
        # totalHospitalizedAtDay = 0
        #check the list once a day
        objectArray[check].increaseDay()
        #remove the index from the list which more than 10 days old
        if (len(indexList)>=1 and objectArray[check].suspiciousDays > 10):
            indexList.remove(check)
        isInfected = objectArray[check].findInfected()
        if isInfected == 1 or objectArray[check].isInfected:
            objectArray[check].positive
            # objectArray[check].printPerson()
            infectedAtDay = infectedAtDay + 1
            #assume that the person is infected, immediately go to hospital
            totalHospitalizedAtDay = totalHospitalizedAtDay + 1
            #if infected that person will not check any more because he/she has immunity for 6 to 7 months
            patientList.append(objectArray[check])  #add the person to the patient list
            # print(patientList)
            # objectArray.remove(objectArray[check])  #remove the patient from the object array
            # if indexList.count(check)>0:
            #     indexList.remove(check)

    return totalHospitalizedAtDay, infectedAtDay
            

dailyInfected = []
dailyHospitalized = [] 
dailyRecovered = []
dailyDeaths = []

for day in range(1,51):
    list3 = list(dict.fromkeys(patientList))
    # print("Previous Day patients at day begining",len(patientList))
    # patientList.clear()
    totalDeathAtDay = 0
    recoveredAtDay = 0 
    
    print("Are people enforced to wear masks in day  ",day)
    isWearingMask = input("Enter 1 if yes Enter any other number if no  : ")
    # isWearingMask=1
    print("Are there travelling restrictions in day ",day)
    travelling = input("Enter 1 if yes Enter any other number if no : ")
    # travelling=1

    if(isWearingMask == 1):
      wearingMask = 1
    else:
      wearingMask = 0

    if(travelling == 1):
      contactOutsidePeopleUpperLimit = 50
    else:
      contactOutsidePeopleUpperLimit = 20
    count = 0 
    for person in list3:
        totalHospitalizedAtDay, infectedAtDay = simulate(person)


    totalInfected = totalInfected + infectedAtDay
    totalHospitalized = totalHospitalized + totalHospitalizedAtDay
    dailyInfected.append(infectedAtDay)
    dailyHospitalized.append(totalHospitalizedAtDay)
    print('|Total Infected :         |', totalInfected) 
  
    #update pateint list daily
    count = 0 
    for patient in patientList:
        patient.increaseHospitalizeDays()   #INCREASE THE DAYS OF HOSPITALIZED
        count = count+1
        # patient.printPerson()
        if patient.infectedDays >=10:
            recoveredAtDay = recoveredAtDay + 1
            stillInHospital = totalHospitalized - 1


    #take 0.1 of hospitalized people die
    totalDeathAtDay = math.floor(stillInHospital*0.001)
    totalDeath = totalDeath + totalDeathAtDay
    totalRecovered = totalHospitalized - totalDeath
    dailyRecovered.append(totalRecovered)
    dailyDeaths.append(totalDeath)
    print('Day : ', day)
    
    dailyList = [infectedAtDay, totalHospitalizedAtDay, totalDeathAtDay, recoveredAtDay]
    finalList.append(dailyList)
    # print('|Total Infected :         |', totalInfected)
    print('Total infected at day : ', infectedAtDay)
    print('Total hospitalized at day : ', totalHospitalizedAtDay)
    # print('Total recovered at day : ', totalRecovered)
    # print('Total death at day : ', totalDeath)
    # infectedAtDay = 0
    # totalHospitalizedAtDay = 0
    print('#####################################################')
    # previousDayPatientList = patientList 
    # patientList.clear()

    
print('=====================================================')
print('|Total Infected :         |', totalInfected)
print('|Totals Hospitalized :    |', totalHospitalized)
print('|Total Recovered :        |', totalRecovered)
print('|Total Death :            |', totalDeath)
print('=====================================================')

plt.plot(dailyInfected)
plt.ylabel('Infected Per Day')
plt.show()

plt.plot(dailyHospitalized)
plt.ylabel('Hospitalized Per Day')
plt.show()

plt.plot(dailyRecovered)
plt.ylabel('Recovered Per Day')
plt.show()
plt.plot(dailyDeaths)
plt.ylabel('Deaths Per Day')
plt.show()
# Out:
# Are people enforced to wear masks in day   1
# Are there travelling restrictions in day  1
# |Total Infected :         | 3
# Day :  1
# Total infected at day :  3
# Total hospitalized at day :  3
# #####################################################
# Are people enforced to wear masks in day   2
# Are there travelling restrictions in day  2
# |Total Infected :         | 20
# Day :  2
# Total infected at day :  17
# Total hospitalized at day :  17
# #####################################################
# Are people enforced to wear masks in day   3
# Are there travelling restrictions in day  3
# |Total Infected :         | 57
# Day :  3
# Total infected at day :  37
# Total hospitalized at day :  37
# #####################################################
# Are people enforced to wear masks in day   4
# Are there travelling restrictions in day  4
# |Total Infected :         | 102
# Day :  4
# Total infected at day :  45
# Total hospitalized at day :  45
# #####################################################
# Are people enforced to wear masks in day   5
# Are there travelling restrictions in day  5
# |Total Infected :         | 154
# Day :  5
# Total infected at day :  52
# Total hospitalized at day :  52
# #####################################################
# Are people enforced to wear masks in day   6
# Are there travelling restrictions in day  6
# |Total Infected :         | 211
# Day :  6
# Total infected at day :  57
# Total hospitalized at day :  57
# #####################################################
# Are people enforced to wear masks in day   7
# Are there travelling restrictions in day  7
# |Total Infected :         | 273
# Day :  7
# Total infected at day :  62
# Total hospitalized at day :  62
# #####################################################
# Are people enforced to wear masks in day   8
# Are there travelling restrictions in day  8
# |Total Infected :         | 340
# Day :  8
# Total infected at day :  67
# Total hospitalized at day :  67
# #####################################################
# Are people enforced to wear masks in day   9
# Are there travelling restrictions in day  9
# |Total Infected :         | 411
# Day :  9
# Total infected at day :  71
# Total hospitalized at day :  71
# #####################################################
# Are people enforced to wear masks in day   10
# Are there travelling restrictions in day  10
# |Total Infected :         | 487
# Day :  10
# Total infected at day :  76
# Total hospitalized at day :  76
# #####################################################
# Are people enforced to wear masks in day   11
# Are there travelling restrictions in day  11
# |Total Infected :         | 567
# Day :  11
# Total infected at day :  80
# Total hospitalized at day :  80
# #####################################################
# Are people enforced to wear masks in day   12
# Are there travelling restrictions in day  12
# |Total Infected :         | 650
# Day :  12
# Total infected at day :  83
# Total hospitalized at day :  83
# #####################################################
# Are people enforced to wear masks in day   13
# Are there travelling restrictions in day  13
# |Total Infected :         | 737
# Day :  13
# Total infected at day :  87
# Total hospitalized at day :  87
# #####################################################
# Are people enforced to wear masks in day   14
# Are there travelling restrictions in day  14
# |Total Infected :         | 831
# Day :  14
# Total infected at day :  94
# Total hospitalized at day :  94
# #####################################################
# Are people enforced to wear masks in day   15
# Are there travelling restrictions in day  15
# |Total Infected :         | 928
# Day :  15
# Total infected at day :  97
# Total hospitalized at day :  97
# #####################################################
# Are people enforced to wear masks in day   16
# Are there travelling restrictions in day  16
# |Total Infected :         | 1030
# Day :  16
# Total infected at day :  102
# Total hospitalized at day :  102
# #####################################################
# Are people enforced to wear masks in day   17
# Are there travelling restrictions in day  17
# |Total Infected :         | 1137
# Day :  17
# Total infected at day :  107
# Total hospitalized at day :  107
# #####################################################
# Are people enforced to wear masks in day   18
# Are there travelling restrictions in day  18
# |Total Infected :         | 1248
# Day :  18
# Total infected at day :  111
# Total hospitalized at day :  111
# #####################################################
# Are people enforced to wear masks in day   19
# Are there travelling restrictions in day  19
# |Total Infected :         | 1364
# Day :  19
# Total infected at day :  116
# Total hospitalized at day :  116
# #####################################################
# Are people enforced to wear masks in day   20
# Are there travelling restrictions in day  20
# |Total Infected :         | 1485
# Day :  20
# Total infected at day :  121
# Total hospitalized at day :  121
# #####################################################
# Are people enforced to wear masks in day   21
# Are there travelling restrictions in day  21
# |Total Infected :         | 1611
# Day :  21
# Total infected at day :  126
# Total hospitalized at day :  126
# #####################################################
# Are people enforced to wear masks in day   22
# Are there travelling restrictions in day  22
# |Total Infected :         | 1742
# Day :  22
# Total infected at day :  131
# Total hospitalized at day :  131
# #####################################################
# Are people enforced to wear masks in day   23
# Are there travelling restrictions in day  23
# |Total Infected :         | 1878
# Day :  23
# Total infected at day :  136
# Total hospitalized at day :  136
# #####################################################
# Are people enforced to wear masks in day   24
# Are there travelling restrictions in day  24
# |Total Infected :         | 2019
# Day :  24
# Total infected at day :  141
# Total hospitalized at day :  141
# #####################################################
# Are people enforced to wear masks in day   25
# Are there travelling restrictions in day  25
# |Total Infected :         | 2164
# Day :  25
# Total infected at day :  145
# Total hospitalized at day :  145
# #####################################################
# Are people enforced to wear masks in day   26
# Are there travelling restrictions in day  26
# |Total Infected :         | 2315
# Day :  26
# Total infected at day :  151
# Total hospitalized at day :  151
# #####################################################
# Are people enforced to wear masks in day   27
# Are there travelling restrictions in day  27
# |Total Infected :         | 2470
# Day :  27
# Total infected at day :  155
# Total hospitalized at day :  155
# #####################################################
# Are people enforced to wear masks in day   28
# Are there travelling restrictions in day  28
# |Total Infected :         | 2632
# Day :  28
# Total infected at day :  162
# Total hospitalized at day :  162
# #####################################################
# Are people enforced to wear masks in day   29
# Are there travelling restrictions in day  29
# |Total Infected :         | 2798
# Day :  29
# Total infected at day :  166
# Total hospitalized at day :  166
# #####################################################
# Are people enforced to wear masks in day   30
# Are there travelling restrictions in day  30
# |Total Infected :         | 2968
# Day :  30
# Total infected at day :  170
# Total hospitalized at day :  170
# #####################################################
# Are people enforced to wear masks in day   31
# Are there travelling restrictions in day  31
# |Total Infected :         | 3144
# Day :  31
# Total infected at day :  176
# Total hospitalized at day :  176
# #####################################################
# Are people enforced to wear masks in day   32
# Are there travelling restrictions in day  32
# |Total Infected :         | 3323
# Day :  32
# Total infected at day :  179
# Total hospitalized at day :  179
# #####################################################
# Are people enforced to wear masks in day   33
# Are there travelling restrictions in day  33
# |Total Infected :         | 3508
# Day :  33
# Total infected at day :  185
# Total hospitalized at day :  185
# #####################################################
# Are people enforced to wear masks in day   34
# Are there travelling restrictions in day  34
# |Total Infected :         | 3698
# Day :  34
# Total infected at day :  190
# Total hospitalized at day :  190
# #####################################################
# Are people enforced to wear masks in day   35
# Are there travelling restrictions in day  35
# |Total Infected :         | 3892
# Day :  35
# Total infected at day :  194
# Total hospitalized at day :  194
# #####################################################
# Are people enforced to wear masks in day   36
# Are there travelling restrictions in day  36
# |Total Infected :         | 4091
# Day :  36
# Total infected at day :  199
# Total hospitalized at day :  199
# #####################################################
# Are people enforced to wear masks in day   37
# Are there travelling restrictions in day  37
# |Total Infected :         | 4296
# Day :  37
# Total infected at day :  205
# Total hospitalized at day :  205
# #####################################################
# Are people enforced to wear masks in day   38
# Are there travelling restrictions in day  38
# |Total Infected :         | 4508
# Day :  38
# Total infected at day :  212
# Total hospitalized at day :  212
# #####################################################
# Are people enforced to wear masks in day   39
# Are there travelling restrictions in day  39
# |Total Infected :         | 4726
# Day :  39
# Total infected at day :  218
# Total hospitalized at day :  218
# #####################################################
# Are people enforced to wear masks in day   40
# Are there travelling restrictions in day  40
# |Total Infected :         | 4949
# Day :  40
# Total infected at day :  223
# Total hospitalized at day :  223
# #####################################################
# Are people enforced to wear masks in day   41
# Are there travelling restrictions in day  41
# |Total Infected :         | 5175
# Day :  41
# Total infected at day :  226
# Total hospitalized at day :  226
# #####################################################
# Are people enforced to wear masks in day   42
# Are there travelling restrictions in day  42
# |Total Infected :         | 5405
# Day :  42
# Total infected at day :  230
# Total hospitalized at day :  230
# #####################################################
# Are people enforced to wear masks in day   43
# Are there travelling restrictions in day  43
# |Total Infected :         | 5642
# Day :  43
# Total infected at day :  237
# Total hospitalized at day :  237
# #####################################################
# Are people enforced to wear masks in day   44
# Are there travelling restrictions in day  44
# |Total Infected :         | 5885
# Day :  44
# Total infected at day :  243
# Total hospitalized at day :  243
# #####################################################
# Are people enforced to wear masks in day   45
# Are there travelling restrictions in day  45
# |Total Infected :         | 6132
# Day :  45
# Total infected at day :  247
# Total hospitalized at day :  247
# #####################################################
# Are people enforced to wear masks in day   46
# Are there travelling restrictions in day  46
# |Total Infected :         | 6386
# Day :  46
# Total infected at day :  254
# Total hospitalized at day :  254
# #####################################################
# Are people enforced to wear masks in day   47
# Are there travelling restrictions in day  47
# |Total Infected :         | 6644
# Day :  47
# Total infected at day :  258
# Total hospitalized at day :  258
# #####################################################
# Are people enforced to wear masks in day   48
# Are there travelling restrictions in day  48
# |Total Infected :         | 6907
# Day :  48
# Total infected at day :  263
# Total hospitalized at day :  263
# #####################################################
# Are people enforced to wear masks in day   49
# Are there travelling restrictions in day  49
# |Total Infected :         | 7175
# Day :  49
# Total infected at day :  268
# Total hospitalized at day :  268
# #####################################################
# Are people enforced to wear masks in day   50
# Are there travelling restrictions in day  50
# |Total Infected :         | 7447
# Day :  50
# Total infected at day :  272
# Total hospitalized at day :  272
# #####################################################
# =====================================================
# |Total Infected :         | 7447
# |Totals Hospitalized :    | 7447
# |Total Recovered :        | 7332
# |Total Death :            | 115
# =====================================================
